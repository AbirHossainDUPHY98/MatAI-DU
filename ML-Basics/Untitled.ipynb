# %%
list(enumerate(set('Noman')))
# Out:
# [(0, 'n'), (1, 'N'), (2, 'a'), (3, 'm'), (4, 'o')]

# %%
from itertools import product
A = [1,23]
B = [4, 5]

print(*list(product(A, B)))
# Out:
# (1, 4) (1, 5) (23, 4) (23, 5)

# %%
print(*(1,3, 45,5))
# Out:
# 1 3 45 5
